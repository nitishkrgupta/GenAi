# %%
import emoji

# %%
s = "Hello 😍😘😒"
emoji.replace_emoji(s, "")
# Out:
# 'Hello '

# %%
s = "Hello 😍😘😒"
emoji.demojize(s)
# Out:
# 'Hello :smiling_face_with_heart-eyes::face_blowing_a_kiss::unamused_face:'
