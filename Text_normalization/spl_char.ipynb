# %%
with open('data.txt', 'r') as file:
    data = file.read()
    for char in data:
        if not char.isalnum() and not ord(char) == 32:
            data = data.replace(char, "")
print(data)
# Out:
# python is a high level objectðŸðŸðŸ oriented dynamically ðŸŒtyped interpreted scripting as well as programming language
