# %%
from textblob import TextBlob

# %%
text = "corrting the wods for txt normalization"
text1 = "I havv corret the wods for txt normalzation"

corrected_words = TextBlob(text1).correct()
print(corrected_words, type(corrected_words))
# Out:
# i have correct the words for txt normalzation <class 'textblob.blob.TextBlob'>
